# %%
json = {
    'name' : 'Tai',
    'description': ' hi! i need some vacation :)))',
    'group' : '23-5KB-C',
    'program': 'KB',
    
    'nameDean' : ' Petr',
    'description' : 'approve',
    'nameDepartment' : 'K209',
    'headofdepartment': 'Frantis', #who put st

}

# request = dis
# put all infomation
# more complex json in serveral parts

# 3 parts: 
#

# %%
json = {
    'PART1': {
        'name' : 'Tai',
        'description': ' hi! i need some vacation :)))',
        'group' : '23-5KB-C',
        'program': 'KB'
    },
    
    'PART2': {
        'nameDepartment' : 'K209',
        'headofdepartment': 'Frantis', #who put st

    }, 

    'PART3': {
        'nameDean' : ' Petr',
        'description' : 'approve',
    }
    
}

# %%
json = {
    'PART1': {
        'STUDENT':{
            'name' : 'Tai',
            'group' : '23-5KB-C',
            'program': 'KB'
        },
        'REQUEST':{
            'description': ' hi! i need some vacation :)))'
        }
    },

    'PART2': 
    {
        'HEADOFDEPARTMENT': {
            'nameDepartment' : 'K209',
            'headofdepartment': 'Frantis', #who put st

        },

        'SUGGESTION':{
            'description': 'OKE GUD'

        }
    }, 
    
    'PART3': 
    {
        'DEAN':{
            'nameDean' : ' Petr',
            'description' : 'approve',
        },

        'SUGGESTION':{
            'description': 'OKE GUD'
        }
    }
}

# QUESTION: HOW CAN TRAS IN TO TABLES WITH COLUMN-ATTRIBUTE

# store

# %%
json = {
    'id':'001',
    'parts':[
        {
            # create relations form - sections
            'id':'011',
            'name' : 'PART1',
            'sections': [
                {
                'id':'011',
                'name' : 'STUDENT',
                'values':[
                    {
                    'id':'111',
                    'name' : 'name',
                    'value': 'Tai'
                    },

                    {
                    'id':'112',
                    'name' : 'group',
                    'value': '23-5KB-C'
                    }

                ],

                }
            ],

        }

    ],


    'PART1': {
        'STUDENT':{
            'name' : 'Tai',
            'group' : '23-5KB-C',
            'program': 'KB'
        },
        'REQUEST':{
            'description': ' hi! i need some vacation :)))'
        }
    },

    'PART2': 
    {
        'HEADOFDEPARTMENT': {
            'nameDepartment' : 'K209',
            'headofdepartment': 'Frantis', #who put st

        },

        'SUGGESTION':{
            'description': 'OKE GUD'
        }
    }, 
    
    'PART3': 
    {
        'DEAN':{
            'nameDean' : ' Petr',
            'description' : 'approve',
        },

        'SUGGESTION':{
            'description': 'OKE GUD'
        }
    }
}


# QUESTION: HOW CAN TRAS IN TO TABLES WITH COLUMN-ATTRIBUTE

# store 

# final structure --- store in table, with PK, FK, relations


# next; request - not need, sequence of forms, store history of the forms,
# authorization,......

# %% [markdown]
# Tai_make

# %%
# create relations request - sections
# sectiosns is phases of request stuedent, student-teacher, teacher-approver

data = {
    'request0':{
        'id':'',
        'creator_id':'',
        'strartTime': {
            'date': '',
            'time': ''
        },
        'endTime': {
            'date': '',
            'time': ''
        },
        'name':'vacation',
        'detailRequest':{
            'sections':[
                {
                    'id':'',
                    'startTime': {
                        'date': '',
                        'time': ''
                    },
                    'endTime': {
                        'date': '',
                        'time': ''
                    },
                    'name' : 'STUDENT',
                    'value': 'p1'
                },

                {
                    'id':'',
                    'startTime': {
                        'date': '',
                        'time': ''
                    },
                    'endTime': {
                        'date': '',
                        'time': ''
                    },
                    'name' : 'STUDENT-TEACHER',
                    'value': 'p12'
                },
                {
                    'id':'',
                    'startTime': {
                        'date': '',
                        'time': ''
                    },
                    'endTime': {
                        'date': '',
                        'time': ''
                    },
                    'name' : 'TEACHER-DEAN',
                    'value': 'p23'
                }    
            ], 
            'parts':[
                {
                    'PART1': {
                        'STUDENT':{
                            'name' : '',
                            'group' : '',
                            'program': ''
                        },
                        'REQUEST':{
                            'description': ''
                        }
                        
                    }
                },

                {
                    'PART2': {
                        'TEACHER':{
                            'name' : '',
                            'nameDepartment' : 'K209',
                        },
                        'SUGGESTION':{
                            'description': ''
                        }
                        
                    }
                },

                {
                    'PART3': {
                        'DEAN':{
                            'name' : ''
                        },
                        'SUGGESTION':{
                            'description': ''
                        }

                    }
                }
            ]
        }
    }

}
