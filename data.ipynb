# %% [markdown]
# data1.json

# %%
{
    "data":{
        "requests":[
            {
                "id": "1",
                "type": "A1",
                "requesterId": "P01",
                "approverId":"P02",
                "createdAt": "November 15",
                "isCompleted": "False" ,
                "parts":[
                    {
                        "id":"11",
                        "requestId": "1",
                        "isCompleted": "True",
                        "responsiblePersonId": "P01",
                        "items":[
                            {
                                "id": "111",
                                "partId": "11",
                                "isCompleted": "True",
                                "onlyReadContent": "Student Name:",
                                "completedContent": "Nguyen Thanh Hiep",
                                "type":"SID1"
                            },
                            {
                                "id": "111",
                                "partId": "11",
                                "isCompleted": "True",
                                "onlyReadContent": "Student Group:",
                                "completedContent": "23-5-KB-C",
                                "type":"SID2"
                            }
                        ]
                    },
                    {
                        "id":"12",
                        "requestId": "1",
                        "isCompleted": "False",
                        "responsiblePersonId": "P02",
                        "items":[
                            {
                                "id": "121",
                                "partId": "12",
                                "isCompleted": "True",
                                "onlyReadContent": "Teacher Name:",
                                "completedContent": "Petr Frantis",
                                "type":"TID1"
                            },
                            {
                                "id": "122",
                                "partId": "12",
                                "isCompleted": "False",
                                "onlyReadContent": "Teacher Comment:",
                                "completedContent": "",
                                "type":"TC1"
                            },
                            {
                                "id": "123",
                                "partId": "12",
                                "isCompleted": "False",
                                "onlyReadContent": "Teacher Signature:",
                                "completedContent": "",
                                "type":"TS1"
                            }
                        ]
                    }
                ]
            }
        ],
        "requesters":[
            {
            "id":"P01",
            "name": "Thanh Hiep",
            "surname": "Nguyen",
            "email":"thanhhiep.nguyen@unob.cz"
            }
        ],
    
        "approvers":[
            {
            "id":"P02",
            "name": "Petr",
            "surname": "Frantis",
            "email":"petr.frantis@unob.cz"
            }
        ]
    }
}

# %% [markdown]
# data2.json

# %%
{
    "data":{
        "requests": [
            {
                "id":"",
                "creator_id":"", 
                "create_at": "",
                "end_at": "",
                "name":"vacation",
                "detailRequest":{
                    "sections":[
                        {
                            "id":"",
                            "create_at": "",
                            "end_at": "",
                            "name" : "STUDENT",
                            "value": "p1"
                        },

                        {
                            "id":"",
                            "create_at": "",
                            "end_at": "",
                            "name" : "STUDENT-TEACHER",
                            "value": "p12"
                        },
                        {
                            "id":"",
                            "create_at": "",
                            "end_at": "",
                            "name" : "TEACHER-DEAN",
                            "value": "p23"
                        }    
                    ], 
                    "parts":[
                        {
                            "id":"",
                            "create_at": "",
                            "end_at": "",
                            "name" : "STUDENT",
                            "order": 1,
                            "Info":{
                                "id":"",
                                "name" : "",
                                "group" : "23-5KB-C",
                                "program": "",
                                "email": ""
                            },
                            "description": ""
                        },
                        
                        {
                            "id":"",
                            "create_at": "",
                            "end_at": "",
                            "name" : "TEACHER",
                            "order": 2,
                            "Info":{
                                "id":"",
                                "name" : "",
                                "nameDepartment" : "K209",
                                "email": ""
                            },
                            "description": ""
                                
                        },

                        {
                            "id":"",
                            "create_at": "",
                            "end_at": "",
                            "name" : "DEAN",
                            "order": 3,
                            "Info":{
                                "id":"",
                                "name" : "",
                                "email": ""
                            },
                            "description": ""
                        }
                        
                    ]
                },
                "status": "pending"
            }

        ]
    }
}

# %% [markdown]
# data3.json

# %%
{
    "id": "1234",
    "sections": [
      {
        "id": "5678",
        "name": "Submission",
        "parts": [
          {
            "id": "9101",
            "name": "Student Part",
            "items": [
              {
                "id": "1121",
                "name": "Name",
                "value": "Tai"
              },
              {
                "id": "1222",
                "name": "Group",
                "value": "23-5KB-C"
              }
            ]
          }
        ]
      },
      {
        "id": "6789",
        "name": "Teacher Approval",
        "parts": [
          {
            "id": "9101",
            "name": "Student Part",
            "items": [
              {
                "id": "1122",
                "name": "Program",
                "value": "Master"
              }
            ]
          },
          {
            "id": "9103",
            "name": "Teacher Part",
            "items": [
              {
                "id": "1124",
                "name": "Name",
                "value": "Frantis"
              },
              {
                "id": "1224",
                "name": "Department",
                "value": "K209"
              }
            ]
          }
        ]
      },
      {
        "id": "7890",
        "name": "Dean Approval",
        "parts": [
          {
            "id": "9101",
            "name": "Student Part",
            "items": [
              {
                "id": "1122",
                "name": "Program",
                "value": "Master"
              }
            ]
          },
          {
            "id": "9103",
            "name": "Teacher Part",
            "items": [
              {
                "id": "1124",
                "name": "Name",
                "value": "Frantis"
              },
              {
                "id": "1224",
                "name": "Department",
                "value": "K209"
              }
            ]
          },
          {
            "id": "9104",
            "name": "Dean Part",
            "items": [
              {
                "id": "1125",
                "name": "Name",
                "value": "Petr"
              }
            ]
          }
        ]
    }
    ]
}

# %% [markdown]
# data4.json

# %%
{
    "data": {
        "requests":[
            {
                "id": "0001",

                "creator": {
                    "id": "00001",
                    "name": "Dang Quy Tai",
                    "email": "quytai.dang@unob.cz"
                },
                
                "parts":[
                    {
                        "id": "0011",
                        "name": "PART1",
                        "sections":[
                            {
                                "id": "0111",
                                "name": "STUDENT",
                                "items":[
                                    {
                                        "id": "1111",
                                        "name": "name",
                                        "value": "Tai"
                                    },
                                    {
                                        "id": "01112",
                                        "name": "group",
                                        "value": "23-5KB-C"
                                    },
                                    {
                                        "id": "01113",
                                        "name": "program",
                                        "value": "Master"
                                    }
                                ]
                            }
                        ]
                    }
                ],

                "PART1":{
                    "STUDENT":{
                        "name":"Tai",
                        "group":"23-5KB-C",
                        "program": "Master"
                    },
                    "REQUEST":{
                        "description":"hi! i need some vacation :)))"
                    }
                },

                "PART2":{
                    "HEADOFDEPARTMENT":{
                        "name":"Frantis",
                        "nameDepartment":"K209"
                    },
                    "SUGGESTION":{
                        "description":"OKE GUD"
                    }
                },

                "PART3":{
                    "DEAN":{
                        "name":"Petr"
                    },
                    "SUGGESTION":{
                        "description":"OKE GUD"
                    }
                }
            }
        ]
    }
}

# %% [markdown]
# data5.json

# %%
{
    "users":[
        {
            "id": "024aea76-1ee8-4fd3-9b62-17aad9d07dc6",
            "name": "Dang Quy Tai",
            "email": "quytai.dang@unob.cz",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now()
        }
    ],

    "requests": [
        {
            "id": "1af7c7a6-9104-11ed-9aef-0242ac110002",
            "name": "STC contest application form",
            "creator_id":"024aea76-1ee8-4fd3-9b62-17aad9d07dc6",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "status": "pending"
        }
    ],
    "formsections": [
        {
            "request_id": "1af7c7a6-9104-11ed-9aef-0242ac110002",
            "id": "1af7c7a6-9104-11ed-9aef-0242ac110002501",
            "name": "Submission",
            "order": 1,
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "status":"submitted"
        },
        {
            "request_id": "1af7c7a6-9104-11ed-9aef-0242ac110002",
            "id": "26b1c646-0a2f-4508-b3e7-56aebe56b017",
            "name": "Teacher Approval",
            "order": 2,
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "status":"approved"
        },
        {
            "request_id": "1af7c7a6-9104-11ed-9aef-0242ac110002",
            "id": "64d485b0-3a45-4b93-9f01-3d59301cefe3",
            "name": "Dean Approval",
            "order": 3,
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "status":"pending"
        }
    ],
    "formparts": [
        {
            "section_id": "78fe6a49-3e4f-4aab-bd55-83b822ec140c",
            "id": "6622876c-cf64-4e6d-a970-4ce63d95c393",
            "name": "Student Part",
            "order": 1,
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now()
            
        },
        {
            "section_id": "26b1c646-0a2f-4508-b3e7-56aebe56b017",
            "id": "ddceaf79-5637-49d0-b4f0-d88f4b8dcf9f",
            "name": "Teacher Part",
            "order": 2,
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now()
            
        },
        {
            "section_id": "64d485b0-3a45-4b93-9f01-3d59301cefe3",
            "id": "44c685d6-04e1-4fff-9ce6-764b7bc11c93",
            "name": "Dean Part",
            "order": 3,
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now()
            
        }
    ],
    "formitems": [
        {
            "part_id":"6622876c-cf64-4e6d-a970-4ce63d95c393",
            "id": "02727e57-412e-4986-965d-c369beebac48",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Name",
            "value": "Dang Quy Tai"
        },
        {
            "part_id":"6622876c-cf64-4e6d-a970-4ce63d95c393",
            "id": "10815df6-ad4b-45ca-8957-3528a31bb67f",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Specialization",
            "value": "Kyberneticka bezpecnost"
        },
        {
            "part_id":"6622876c-cf64-4e6d-a970-4ce63d95c393",
            "id": "f451e384-4e5b-40d6-a49f-59df996f3d66",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Group",
            "value": "23-5KB-C"
        },
        {
            "part_id":"6622876c-cf64-4e6d-a970-4ce63d95c393",
            "id": "f9b5b5a5-5b1f-4b9f-9b1f-5b1f4b9f9b1f",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Program",
            "value": "Mg"
        },
        {
            "part_id":"6622876c-cf64-4e6d-a970-4ce63d95c393",
            "id": "fe85ac55-b30c-4f15-bba5-9f020764779c",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "email",
            "value": "quytai.dang@unob.cz"
        },
        {
            "part_id":"6622876c-cf64-4e6d-a970-4ce63d95c393",
            "id": "d378df0f-f659-4b59-9e78-9d250c6496cf",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Description",
            "value": "I send you my application for STC contest"
        },
        {
            "part_id":"6622876c-cf64-4e6d-a970-4ce63d95c393",
            "id": "f9b5b5a5-5b1f-4b9f-9b1f-5b1f4b9fasdf44",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Status",
            "value": "submitted"
        },
        {
            "part_id":"ddceaf79-5637-49d0-b4f0-d88f4b8dcf9f",
            "id": "8df55c6f-3109-4b37-a1c7-3de1dfd1e404",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Name",
            "value": "Petr Frantis"
        },
        {
            "part_id":"ddceaf79-5637-49d0-b4f0-d88f4b8dcf9f",
            "id": "a0b5b5a5-5b1f-4b9f-9b1f-5b1f4b9f9b1f",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "email",
            "value": "petr.fratis@unob.cz"
        },
        {
            "part_id":"ddceaf79-5637-49d0-b4f0-d88f4b8dcf9f",
            "id": "b26dcf77-99d2-4d61-b811-e9b8d35ef2f7",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Department",
            "value": "K209"
        },
        {
            "part_id":"ddceaf79-5637-49d0-b4f0-d88f4b8dcf9f",
            "id": "c26dcf77-99d2-4d61-b811-e9b8d35ef2f7",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Description",
            "value": "I have received your application. Application has been approved. I agree to be your supervisor."
        },
        {
            "part_id":"ddceaf79-5637-49d0-b4f0-d88f4b8dcf9f",
            "id": "d26dcf77-99d2-4d61-b811-e9b8d35ef2f7",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Status",
            "value": "approved"
        },
        {
            "part_id":"44c685d6-04e1-4fff-9ce6-764b7bc11c93",
            "id": "cb84f761-1478-4cad-9196-e3c7242d89b2",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Name",
            "value": "Frantisek Vojkovsky"
        },
        {
            "part_id":"44c685d6-04e1-4fff-9ce6-764b7bc11c93",
            "id": "d0b5b5a5-5b1f-4b9f-9b1f-5b1f4b9f9b1f",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "email",
            "value": "frantisek.vojkovsky@unob.cz"
        },
        {
            "part_id":"44c685d6-04e1-4fff-9ce6-764b7bc11c93",
            "id": "d26dcf77-99d2-4d61-b811-e9b8d35ef2f7",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Department",
            "value": "K111"
        },
        {
            "part_id":"44c685d6-04e1-4fff-9ce6-764b7bc11c93",
            "id": "e26dcf77-99d2-4d61-b811-e9b8d35ef2f7",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Description",
            "value": "From the dean's office: your application will be on a waiting list. The list of contestants will be announced on January 10, 2023"
        },
        {
            "part_id":"44c685d6-04e1-4fff-9ce6-764b7bc11c93",
            "id": "f26dcf77-99d2-4d61-b811-e9b8d35ef2f7",
            "create_at":datetime.datetime.now(),
            "lastchange":datetime.datetime.now(),
            "name": "Status",
            "value": "pending"
        }
    ]
}
