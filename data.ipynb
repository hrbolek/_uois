# %%
json = {
    'name' : 'Tai',
    'description': ' hi! i need some vacation :)))',
    'group' : '23-5KB-C',
    'program': 'KB',
    
    'nameDean' : ' Petr',
    'description' : 'approve',
    'nameDepartment' : 'K209',
    'headofdepartment': 'Frantis', #who put st

}

# request = dis
# put all infomation
# more complex json in serveral parts

# 3 parts: 
#

# %%
json = {
    'PART1': {
        'name' : 'Tai',
        'description': ' hi! i need some vacation :)))',
        'group' : '23-5KB-C',
        'program': 'KB'
    },
    
    'PART2': {
        'nameDepartment' : 'K209',
        'headofdepartment': 'Frantis', #who put st

    }, 

    'PART3': {
        'nameDean' : ' Petr',
        'description' : 'approve',
    }
    
}

# %%
json = {
    'PART1': {
        'STUDENT':{
            'name' : 'Tai',
            'group' : '23-5KB-C',
            'program': 'KB'
        },
        'REQUEST':{
            'description': ' hi! i need some vacation :)))'
        }
    },

    'PART2': 
    {
        'HEADOFDEPARTMENT': {
            'nameDepartment' : 'K209',
            'headofdepartment': 'Frantis', #who put st

        },

        'SUGGESTION':{
            'description': 'OKE GUD'

        }
    }, 
    
    'PART3': 
    {
        'DEAN':{
            'nameDean' : ' Petr',
            'description' : 'approve',
        },

        'SUGGESTION':{
            'description': 'OKE GUD'
        }
    }
}

# QUESTION: HOW CAN TRAS IN TO TABLES WITH COLUMN-ATTRIBUTE

# store

# %%
json = {
    'id':'001',
    'parts':[
        {
            # create relations form - sections
            'id':'011',
            'name' : 'PART1',
            'sections': [
                {
                'id':'011',
                'name' : 'STUDENT',
                'items':[   #thầy thì ghi cái này là values
                    {
                    'id':'111',
                    'name' : 'name',
                    'item': 'Tai'
                    },

                    {
                    'id':'112',
                    'name' : 'group',
                    'item': '23-5KB-C'
                    }

                ],

                }
            ],

        }

    ],


    'PART1': {
        'STUDENT':{
            'name' : 'Tai',
            'group' : '23-5KB-C',
            'program': 'KB'
        },
        'REQUEST':{
            'description': ' hi! i need some vacation :)))'
        }
    },

    'PART2': 
    {
        'HEADOFDEPARTMENT': {
            'nameDepartment' : 'K209',
            'headofdepartment': 'Frantis', #who put st

        },

        'SUGGESTION':{
            'description': 'OKE GUD'
        }
    }, 
    
    'PART3': 
    {
        'DEAN':{
            'nameDean' : ' Petr',
            'description' : 'approve',
        },

        'SUGGESTION':{
            'description': 'OKE GUD'
        }
    }
}


# QUESTION: HOW CAN TRAS IN TO TABLES WITH COLUMN-ATTRIBUTE

# store 

# final structure --- store in table, with PK, FK, relations


# next; request - not need, sequence of forms, store history of the forms,
# authorization,......

# %% [markdown]
# Requests
# +----+-------------+
# | PK | Description |
# +----+-------------+
# |  1 | hi! i need some vacation :))) |
# +----+-------------+
#
# Parts
# +----+--------+---------+
# | PK | Request |  Name   |
# +----+--------+---------+
# |  1 |      1 | PART1   |
# |  2 |      1 | PART2   |
# |  3 |      1 | PART3   |
# +----+--------+---------+
#
# Sections
# +----+--------+--------+
# | PK |  Part  |  Name  |
# +----+--------+--------+
# |  1 |      1 | STUDENT |
# |  2 |      1 | REQUEST |
# |  3 |      2 | HEADOFDEPARTMENT |
# |  4 |      2 | SUGGESTION |
# |  5 |      3 | DEAN |
# |  6 |      3 | SUGGESTION |
# +----+--------+--------+
#
# Items
# +----+--------+--------+--------+
# | PK | Section |  Name  | Item  |
# +----+--------+--------+--------+
# |  1 |      1 | name   | Tai    |
# |  2 |      1 | group  | 23-5KB-C |
# |  3 |      1 | program| KB |
# |  4 |      2 | description | hi! i need some vacation :))) |
# |  5 |      3 | nameDepartment | K209 |
# |  6 |      3 | headofdepartment | Frantis |
# |  7 |      4 | description | OKE GUD |
# |  8 |      5 | nameDean | Petr |
# |  9 |      5 | description | approve |
# | 10 |      6 | description | OKE GUD |
# +----+--------+--------+--------+
